# %%
import matplotlib.pyplot as plt
months=['Jan','Feb','Mar','Apr','May']
sales=[300,450,150,400,600] # Changed from set to list
plt.plot(months,sales,color='red',marker='o',linestyle='--')
plt.title('Monthly Sales Report')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.grid(True) # Corrected grid function call
plt.show()

# %%
products=['phone','tv','laptop','earpods','powerbank']
revenue=[200000,300000,250000,75000,65000]
plt.bar(products,revenue,color='green')
plt.title('Revenue by Product Category')
plt.xlabel('Products')
plt.ylabel('Revenue')
plt.show()

# %%
age=[18,25,30,35,40]
salary=[15000,30000,40000,50000,60000]
plt.scatter(age,salary,color='orange')
plt.title('Age vs Salary Relationship')
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# %%
brands=['boat','jbl','sony','oneplus','nothing','apple']
market_share=[25,30,20,35,45,40]
colors=['gold','silver','lightblue','lightgreen','lightpink','orange']
plt.pie(market_share,labels=brands,colors=colors,autopct='%1.1f%%',startangle=90)
plt.title('Mobile Market Share')
plt.show()

# %%
import numpy as np
ages=np.random.randint(18,60,100)
plt.hist(ages,bins=6,color='lavender',edgecolor='black')
plt.title("Age Distribution of Employees")
plt.xlabel("Age Groups")
plt.ylabel("Count")
plt.show()

# %%
x=[1,2,3,4,5]
y1=[10,20,30,40,50]
y2=[15,20,25,30,35]
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(x,y1,'r--')
plt.title('Line PLot')
plt.subplot(1,2,2)
plt.bar(x,y2,color='lightgreen')
plt.title('Bar Plot')
plt.tight_layout()
plt.show()

# %%
plt.style.use('ggplot')
x=[1,2,3,4,5]
sales=[10,20,30,25,50]
profit=[2,5,8,6,10]
plt.plot(x,sales,label='Sales',marker='o')
plt.plot(x,profit,label='Profit',marker='s')
plt.title('Sales vs Profit Trend')
plt.xlabel("Quarter")
plt.ylabel("Amount")
plt.legend()
plt.savefig("sales_profit_chart.png")
plt.show()

# %%
from google.colab import drive
import pandas as pd

drive.mount('/content/drive')
path='/content/drive/MyDrive/data.csv'
df=pd.read_csv(path)
print(df.shape)
print(df.info)
print(df.isnull().sum())
ini=df.shape[0]
df.drop_duplicates(inplace=True)
rows=ini-df.shape[0]
print(rows)
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
missing_dates_count = df['Date'].isnull().sum()
print(f"Number of missing or invalid dates: {missing_dates_count}")
df.sort_values(by='Date', inplace=True)
display(df.head())
numeric_cols_with_missing = df.select_dtypes(include=np.number).columns[df.select_dtypes(include=np.number).isnull().any()]
print("Numeric columns with missing values:", numeric_cols_with_missing)
for col in numeric_cols_with_missing:
    median_val = df[col].median()
    df[col].fillna(median_val, inplace=True)
    print(f"Filled missing values in '{col}' with the median: {median_val}")
print("\nMissing values per column after filling:")
print(df.isnull().sum())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (32, 5)
# <bound method DataFrame.info of     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# ...

# %% [markdown]
# •  Inspect the dataset and list the number of rows, columns, data types, and any missing values.
# •  Remove duplicate rows (if any) and re-check the dataset — how many rows were removed?
# •  Parse the Date column to datetime, sort the data by date, and report how many rows (if any) have invalid/missing dates.
# •  Handle missing values in numeric columns (explain and apply a method you choose), then state which method you used and why

# %%
import matplotlib.pyplot as plt

plt.plot(df['Date'], df['Calories'], color='red', marker='o', linestyle='--')
plt.title('Calories Over Time')
plt.xlabel('Date')
plt.ylabel('Calories')
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.grid(True)
plt.savefig("line_calories_over_time.png") # Save the figure
plt.show()

# %% [markdown]
# Create a line plot of Calories over Date (with markers, dashed line, grid, rotated x-ticks) and save the image as line_calories_over_time.png.

# %%
average_pulse_by_duration = df.groupby('Duration')['Pulse'].mean().reset_index()


plt.bar(average_pulse_by_duration['Duration'], average_pulse_by_duration['Pulse'], color='blue')
plt.title('Average Pulse by Duration')
plt.xlabel("Duration")
plt.ylabel("Average Pulse")
plt.xticks(average_pulse_by_duration['Duration']) # Ensure all duration values are shown as ticks
plt.show()


plt.savefig("bar_avg_pulse_by_duration.png")

# %%
import numpy as np
from scipy.stats import pearsonr

Duration=[6,7,3,4,2]
Calories=[100,150,200,250,300]

# Compute Pearson correlation coefficient
corr, _ = pearsonr(Duration, Calories)
print(f'Pearson correlation coefficient: {corr:.3f}')

plt.scatter(Duration,Calories,color='orange')

# Add linear trend line
m, b = np.polyfit(Duration, Calories, 1)
plt.plot(Duration, m*np.array(Duration) + b, color='blue')

plt.title('Duration vs Calories')
plt.xlabel("Duration")
plt.ylabel("Calories")
plt.show()
plt.savefig("scatter_duration_vs_calories.png")
# Out:
# Pearson correlation coefficient: -0.839

# %%
ranges=['<=120','121-140','141-160','>160']
max_pulse=[25,30,20,35]
colors=['gold','silver','lightblue','lightgreen']
plt.pie(max_pulse,labels=ranges,colors=colors,autopct='%1.1f%%',startangle=90)
plt.title('Percentage Breakdown of Maxpulse')
plt.show()
plt.savefig("pie_maxpulse_ranges.png")

# %%
import numpy as np
# Plot a histogram of Calories
plt.hist(df['Calories'], bins=10, color='skyblue', edgecolor='black') # Using 10 bins as an appropriate number
plt.title("Distribution of Calories")
plt.xlabel("Calories")
plt.ylabel("Frequency")
plt.grid(axis='y', alpha=0.75)
plt.show()

# The histogram appears to be slightly right-skewed, indicating that there are more instances of lower calorie counts than higher ones.

plt.savefig("hist_calories.png")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))


plt.subplot(1, 2, 1)
plt.plot(df['Date'], df['Pulse'], marker='o', linestyle='-', color='red')
plt.title('Pulse Over Time')
plt.xlabel('Date')
plt.ylabel('Pulse')
plt.xticks(rotation=45)
plt.grid(True)

plt.subplot(1, 2, 2)
plt.scatter(df['Duration'], df['Maxpulse'], color='blue')
plt.title('Duration vs Maxpulse')
plt.xlabel('Duration')
plt.ylabel('Maxpulse')
plt.grid(True)


plt.tight_layout()


plt.savefig("subplots_pulse_duration_maxpulse.png")
plt.show()

# %% [markdown]
# Group data by Duration (or sensible duration bins), compute the average Pulse per group, and draw a bar chart comparing average pulse across duration groups; save as bar_avg_pulse_by_duration.png.
#
# •  Plot a scatter plot of Duration vs Calories, compute the Pearson correlation coefficient, and add a linear trend line to the scatter; save as scatter_duration_vs_calories.png.
# •  Create a pie chart showing the percentage breakdown of Maxpulse into ranges (e.g., <=120, 121–140, 141–160, >160) and save as pie_maxpulse_ranges.png.
# •  Plot a histogram of Calories with an appropriate number of bins, comment on shape/skewness, and save as hist_calories.png.
# •  Build a multi-panel subplot figure (1 row × 2 columns): left = line plot of Pulse over Date, right = scatter of Duration vs Maxpulse; save as subplots_pulse_duration_maxpulse.png.

# %%
from google.colab import drive
import pandas as pd

drive.mount('/content/drive')
path='/content/drive/MyDrive/tip(in).csv'
df=pd.read_csv(path)
print(df.info())
print(df.head())
print(df.isnull().sum())
# Out:
# Mounted at /content/drive
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
# None
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# total_bill    0
# tip           0
# sex           0
# smoker        0
# ...

# %%
plt.plot(df['tip'], df['time'], color='red', marker='o', linestyle='--')
plt.title('Tip Over Time')
plt.xlabel('Tip')
plt.ylabel('Tip')
 # Rotate x-axis labels for better readability
plt.grid(True)
# Save the figure
plt.show()

# %%
import matplotlib.pyplot as plt

# Group data by 'day' and 'sex' and calculate the mean tip
average_tip_by_day= df.groupby(['day'])['tip'].mean().reset_index()

# Create a grouped bar chart
plt.figure(figsize=(12, 6))
plt.bar(df['day'], df['tip'], data=average_tip_by_day, color='lightblue')
plt.title('Average Tip by Day ')
plt.xlabel('Day of the Week')
plt.ylabel('Average Tip')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
import matplotlib.pyplot as plt
# Plot a histogram of total_bill
plt.hist(df['total_bill'], bins=15, color='skyblue', edgecolor='black') # Using 15 bins for better visualization
plt.title("Distribution of Total Bill")
plt.xlabel("Total Bill")
plt.ylabel("Frequency")
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt



plt.scatter(df['tip'],df['total_bill'],color='orange')



plt.title('TIP vs TOTALBILLS')
plt.xlabel("Tip")
plt.ylabel("Total bills")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


data = [df['tip'], df['total_bill']]
plt.boxplot(data, tick_labels=['Tip', 'Total Bill'])

plt.title('Box Plot of Tip and Total Bill')
plt.xlabel("Data")
plt.ylabel("Values")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))


plt.subplot(1, 2, 1)
plt.plot(df['day'], df['total_bill'], marker='o', linestyle='-', color='red')
plt.title('Total bill by day')
plt.xlabel('Day')
plt.ylabel('Total bill')
plt.xticks(rotation=45)
plt.grid(True)

plt.subplot(1, 2, 2)
plt.scatter(df['day'], df['tip'], color='blue')
plt.title('Tip by day')
plt.xlabel('Day')
plt.ylabel('Tips')
plt.grid(True)


plt.tight_layout()



plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.set_theme(style='whitegrid')

# Load example datasets
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')

print('Datasets loaded: tips (rows={}), iris (rows={})'.format(len(tips), len(iris)))

tips.head()
# Out:
# Datasets loaded: tips (rows=244), iris (rows=150)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(tips['total_bill'], kde=False)
plt.title('Histogram - Distribution of Total Bill')
plt.show()

# KDE Plot
sns.kdeplot(tips['total_bill'])
plt.title('KDE Plot - Smooth Distribution of Total Bill')
plt.show()

# Displot (Histogram + KDE)
sns.displot(tips['total_bill'], kde=True)
plt.title('Displot - Total Bill Distribution')
plt.show()

# %% [markdown]
# ## 3. Categorical Plots (Why: compare groups/categories)
#
# - **Barplot** (`sns.barplot`): shows aggregate (mean) for categories.
# - **Countplot** (`sns.countplot`): shows counts of categorical values.
# - **Boxplot** (`sns.boxplot`): shows median, quartiles, and outliers.
# - **Violinplot** (`sns.violinplot`): boxplot + KDE.
#
# Use `hue` to split by another categorical variable.

# %%
# Bar Plot - Average Tip by Gender
sns.barplot(x='sex', y='tip', data=tips)
plt.title('Bar Plot - Average Tip by Gender')
plt.show()

# Count Plot - Frequency of Days
sns.countplot(x='day', data=tips)
plt.title('Count Plot - Frequency of Days')
plt.show()

# Box Plot - Total Bill by Day
sns.boxplot(x='day', y='total_bill', data=tips)
plt.title('Box Plot - Total Bill by Day')
plt.show()

# Violin Plot - Distribution + Summary
sns.violinplot(x='day', y='total_bill', data=tips)
plt.title('Violin Plot - Total Bill by Day')
plt.show()

# %% [markdown]
# 4. Relationship Plots (Why: see how two numeric variables relate)
# Scatterplot (sns.scatterplot): point cloud to inspect correlation.
# Lineplot (sns.lineplot): trends over an ordered variable.
# Relplot (sns.relplot): figure-level interface for relational plots; supports faceting.

# %%
# Scatter Plot - Total Bill vs Tip
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex')
plt.title('Scatter Plot - Total Bill vs Tip')
plt.show()

# Line Plot - Tip vs Party Size (useful for trend-like visuals)
sns.lineplot(x='size', y='tip', data=tips)
plt.title('Line Plot - Tip vs Party Size')
plt.show()

# Relplot with Facets
sns.relplot(x='total_bill', y='tip', hue='sex', col='day', data=tips)
plt.suptitle('Relplot - Tip vs Total Bill by Day & Gender', y=1.02)
plt.show()

# %% [markdown]
# Matrix & Correlation Plots (Why: inspect relationships between many variables)
# Heatmap (sns.heatmap): visualize correlation matrix or any 2D numerical table.
# Clustermap (sns.clustermap): heatmap + hierarchical clustering to find groups.

# %%
# Select only numeric columns
iris_num = iris.select_dtypes(include=['float', 'int'])

# Compute correlation
corr = iris_num.corr()

# Plot the heatmap
sns.heatmap(corr, annot=True,cmap='coolwarm')
plt.title("Heatmap - Correlation of Iris Features")
plt.show()

# Select only numeric columns (exclude 'species')
iris_num = iris.select_dtypes(include=['float', 'int'])

# Compute correlation matrix
corr = iris_num.corr()

# Create the clustermap
sns.clustermap(corr, cmap='coolwarm', annot=True)
plt.suptitle('Clustermap - Grouped Correlations (Numeric Only)', y=1.02)
plt.show()

# %%
from google.colab import drive
import pandas as pd

drive.mount('/content/drive')
path='/content/drive/MyDrive/Customer_support_data.csv'
df=pd.read_csv(path)

print("Missing values before removal:")
print(df.isnull().sum())

init=df.shape[0]
# Remove duplicate rows
df.drop_duplicates(inplace=True)
rows_removed_duplicates = init - df.shape[0]
print(f"\nNumber of duplicate rows removed: {rows_removed_duplicates}")

# Remove rows with any missing values
df.dropna(inplace=True)
rows_removed_missing = init - df.shape[0] - rows_removed_duplicates
print(f"Number of rows removed due to missing values: {rows_removed_missing}")

print("\nMissing values after removal:")
print(df.isnull().sum())
print("\nShape of the DataFrame after removal:")
print(df.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Missing values before removal:
# Unique id                      0
# channel_name                   0
# category                       0
# Sub-category                   0
# Customer Remarks           57165
# Order_id                   18232
# order_date_time            68693
# Issue_reported at              0
# issue_responded                0
# Survey_response_Date           0
# Customer_City              68828
# Product_category           68711
# Item_price                 68701
# connected_handling_time    85665
# Agent_name                     0
# Supervisor                     0
# Manager                        0
# Tenure Bucket                  0
# Agent Shift                    0
# CSAT Score                     0
# dtype: int64
#
# Number of duplicate rows removed: 0
# Number of rows removed due to missing values: 85869
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['Item_price'], kde=False)
plt.title('Histogram - Distribution of Item Price')
plt.show()
sns.boxplot(x=df['CSAT Score'],color='lightpink')
plt.title('Box Plot - CSAT Score')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 5))

# Histogram plot of connected_handling_time
plt.subplot(1, 2, 1)
sns.histplot(df['connected_handling_time'], color='red')
plt.title('Histogram of Connected Handling Time')
plt.xlabel('Connected Handling Time')
plt.ylabel('Frequency')

# Boxplot of connected_handling_time
plt.subplot(1, 2, 2)
sns.boxplot(x=df['connected_handling_time'], color='blue')
plt.title('Box Plot of Connected Handling Time')
plt.xlabel('Connected Handling Time')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Calculate the value counts for CSAT Score
csat_counts = df['CSAT Score'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(csat_counts, labels=csat_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired(range(len(csat_counts))))
plt.title('Percentage Breakdown of CSAT Score Values')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot a histogram of Item_price to show the distribution in price ranges
plt.hist(df['Item_price'], bins=10, color='salmon', edgecolor='black') # Using 10 bins as an example
plt.title('Distribution of Item Prices')
plt.xlabel('Item Price Ranges')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a countplot to show the number of tickets from each channel_name
sns.countplot(x='channel_name', data=df)
plt.title('Number of Tickets by Channel Name')
plt.xlabel('Channel Name')
plt.ylabel('Number of Tickets')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get the counts of each category and sort them
category_counts = df['category'].value_counts().reset_index()
category_counts.columns = ['category', 'count']
category_counts = category_counts.sort_values(by='count', ascending=False)

# Create a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='category', y='count', data=category_counts)
plt.title('Number of Tickets by Category (Sorted)')
plt.xlabel('Category')
plt.ylabel('Number of Tickets')
plt.xticks(rotation=45, ha='right') # Rotate labels for better readability
plt.tight_layout() # Adjust layout
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Calculate the value counts for Agent Shift
shift_counts = df['Agent Shift'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(shift_counts, labels=shift_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired(range(len(shift_counts))))
plt.title('Distribution of Tickets by Agent Shift')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get the counts of each Sub-category and select the top 10
subcategory_counts = df['Sub-category'].value_counts().nlargest(10).reset_index()
subcategory_counts.columns = ['Sub-category', 'count']

# Create a horizontal bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='count', y='Sub-category', data=subcategory_counts)
plt.title('Top 10 Sub-category Values')
plt.xlabel('Number of Tickets')
plt.ylabel('Sub-category')
plt.show()

# %%
ticket_counts = df['Tenure Bucket'].value_counts().reset_index()
ticket_counts.columns = ['Tenure Bucket', 'count']

# Create a horizontal bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='count', y='Tenure Bucket', data=ticket_counts)
plt.title('Barplot')
plt.xlabel('count')
plt.ylabel('Tenure Bucket')
plt.show()

# %%
sns.scatterplot(df['Item_price'],df['CSAT Score'],color='lightblue')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3131312030.py in <cell line: 0>()
# ----> 1 sns.scatterplot(df['Item_price'],df['CSAT Score'],color='lightblue')
#       2 plt.show()
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given
